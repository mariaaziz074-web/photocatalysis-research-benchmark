# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Benchmark Dataset: Exploratory Data Analysis & Chemical Space Audit\n",
    "**Project:** `photocatalysis-research-benchmark`  \n",
    "**Target Journal:** *Scientific Data* (Nature Portfolio)  \n",
    "**Objective:** Inspect data distributions, verify physical descriptor boundaries, evaluate feature correlations, and audit provenance."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import os\n",
    "import sys\n",
    "from pathlib import Path\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Set project root\n",
    "PROJECT_ROOT = Path(\".\").resolve().parent if Path(\".\").resolve().name == \"notebooks\" else Path(\".\").resolve()\n",
    "sys.path.insert(0, str(PROJECT_ROOT / \"src\"))\n",
    "\n",
    "from photocatalysis_benchmark.analysis.eda import (\n",
    "    plot_figure_1_dataset_overview,\n",
    "    plot_figure_2_chemical_space,\n",
    "    plot_figure_3_correlation_heatmap,\n",
    "    plot_figure_4_kinetics_overview\n",
    ")\n",
    "\n",
    "print(f\"Project root resolved to: {PROJECT_ROOT}\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Load Validated Dataset"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "data_path = PROJECT_ROOT / \"data\" / \"interim\" / \"validated_photocatalysis_dataset.csv\"\n",
    "if not data_path.exists():\n",
    "    data_path = PROJECT_ROOT / \"data\" / \"raw\" / \"raw_photocatalysis_dataset.csv\"\n",
    "\n",
    "df = pd.read_csv(data_path)\n",
    "print(f\"Total records loaded: {len(df)}\")\n",
    "print(f\"Total features/columns: {len(df.columns)}\")\n",
    "df.head(5)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Descriptive Summary Statistics"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "num_cols = [\n",
    "    \"bandgap_ev\", \"surface_area_m2g\", \"catalyst_dosage_gl\",\n",
    "    \"initial_dye_conc_mgl\", \"ph\", \"light_intensity_mwcm2\",\n",
    "    \"reaction_time_min\", \"degradation_efficiency_percent\", \"rate_constant_k_min1\"\n",
    "]\n",
    "df[num_cols].describe().T"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Provenance & Diversity Breakdown"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print(\"=== PROVENANCE METRICS ===\")\n",
    "print(f\"Unique DOIs: {df['source_doi'].nunique()}\")\n",
    "print(f\"Unique Photocatalysts: {df['catalyst_name'].nunique()}\")\n",
    "print(f\"Unique Target Dyes: {df['dye_name'].nunique()}\")\n",
    "print(f\"Unique Irradiation Types: {df['light_source_type'].nunique()}\")\n",
    "\n",
    "if \"quality_tier\" in df.columns:\n",
    "    print(\"\\nQuality Tier Distribution:\")\n",
    "    print(df[\"quality_tier\"].value_counts(normalize=True) * 100)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Publication Visualizations (Figures 1-4)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "figs_dir = PROJECT_ROOT / \"results\" / \"figures\"\n",
    "figs_dir.mkdir(parents=True, exist_ok=True)\n",
    "\n",
    "plot_figure_1_dataset_overview(df, figs_dir / \"fig1_dataset_overview.png\")\n",
    "plot_figure_2_chemical_space(df, figs_dir / \"fig2_chemical_space.png\")\n",
    "plot_figure_3_correlation_heatmap(df, figs_dir / \"fig3_correlation_heatmap.png\")\n",
    "plot_figure_4_kinetics_overview(df, figs_dir / \"fig4_kinetics_overview.png\")\n",
    "\n",
    "print(\"Figures generated successfully in results/figures/\")"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
